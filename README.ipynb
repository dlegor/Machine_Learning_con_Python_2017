# %% [markdown]
# Tutorial de Aprendizaje Automático con Scikit-learn
# ===================================================
#
#
# Instructores:
# ------------
#
# * Fabiola Rodriguez
# * Daniel Legorreta
#
# Comentarios e instrucciones:
# ---------------------------------
#
# En el siguiente textos encontrarás todas las instrucciones a seguir para validar que se cuenta con lo necesario para realizar el tutorial. Si tienen experiencia con Python muchas de las instrucciones te resultarán normales o sencillas, en el caso de contar con poco conocimiento de este lenguaje de programación sigue las instrucciones de este texto paso a paso.
#
# Todas los nombre que resaltan con color [azul](), cuentan con hipervínculos para dirigirte algun sitio de internet donde se aclara o explica más sobre lo relacionado a esa nombre.
#
#
#
# ## Repositorio:
#
#
# Todo el material se encuentra disponible de manera gratuita en el el repositorio:
#
# * [Machine_Learning_con_Python_2017](https://github.com/dlegor/Machine_Learning_con_Python_2017)
#
#
# ¿Cómo descargar el material del taller?
#
# * Las instrucciones desde Github: basta con ir a la dirección del repositorio y descargar el en modo zip el contenido:
#
# [https://github.com/dlegor/Machine_Learning_con_Python_2017](https://github.com/dlegor/Machine_Learning_con_Python_2017)
#
# La descarga se realiza seleccionando el botón *Clone or download*:
# ![](Imagenes/Descarga_Zip.png)
#
# Instrucciones desde línea de comandos.
#
# ```bash
# git remote add upstream https://github.com/dlegor/Machine_Learning_con_Python_2017.git
# git fetch upstream
# git checkout master merge upstream/master
#
# ```
#
# ## Entorno.
#
#
# Para seguir los ejemplos del tutorial se necesita contar con los paquetes siguientes:
#
# * [NumPy](http://www.numpy.org/)
# * [SciPy](https://www.scipy.org/)
# * [matplotlib](http://matplotlib.org/)
# * [seaborn](https://seaborn.pydata.org/)
# * [Pandas](http://pandas.pydata.org/)
# * [IPython](https://ipython.org/)
# * [Jupyter Notebook](http://jupyter.org/)
# * [Scikit-Learn](http://scikit-learn.org/stable/)
# * [StatsModels](http://www.statsmodels.org/stable/index.html)
# * [PyYaml](http://pyyaml.org/)
#
# Para validar que se cuenta con lo necesario se ejecuta el script *entorno.py*, se puede hacer de las siguientes formas:
#
# * Desde consola
# * Desde un Notebook
#
# Desde *consola* basta con ubicarnos en el directorio correspondiente al material, identificar el script con el nombre *entorno.py* y ejecutar la siguiente instrucción en la línea de comandos. Las instrucciones serían las siguientes:
#
# ```bash
#
# cd /Directorio/donde/se/ubica/el/material
#
# #Ubicado en el directorio Notas_Curso_ML_2017
# python entorno.py
#
# ```
#
# La salida en la terminal se mostrará de la siguiente forma:
# ![](Imagenes/Pantalla_salida_entorno.png)
#
# Desde un *Notebook* se debe primero ejecutar en la linea de comandos desde la ruta o posición que se desee (de preferencia en la ruta de las notas) lo siguiente:
#
# ``` bash
# jupyter notebook
#
# ```
#
# Esto abrirá un servicio en el browser que se tenga asignado como predeterminado, de preferencia abrilo en Google Chrome o Firefox. En la pestaña del browser se visualizará lo siguiente:
#
# ![]()
#
# Haz doble click o abre el notebook que tiene por nombre **Validacion_Entorno.ipynb**, este cuenta con dos celdas que tienen las siguente instrucciones:
#
# ``` bash
#
# %run entorno.py
#
# #Se encuentran en celdas separadas
#
# %run instalaciones_faltantes.py
#
# ```
# Para ejecutar solo se tienen que presionar en el botón de *run cell* para cada celda seleccionada, en la siguiente imagen se muestra:
#
# ![](Imagenes/Una_celda.png)
#
#
# Para ejecutar todas las celdas se elige la opcion en el *Menú-> cell->Run All*, la siguiente imagen muestra como ejecutarlo:
#
# ![](Imagenes/Celds_Todas.png)
#
#
# ## Datos del Tutorial
#
#
# Si descargas las notas del taller desde el repositorio en Github contarás con ellos, en todo caso si por alguna razón no se cuentan con ellos se pueden descargar con el script *datos_taller.py*. Estos crearán las carpetas necesarias dentro del directorio *DataSets*.
#
# Las instrucciones de ejecución son similares a las realizadas para validar el entorno, tanto para la ejecución en consola como en un notebook.
#
# ## Lista de referencias.
#
#
# ## Agradecimietos.
#
# El material del talles no sería posible sin toda la documentación disponible en las páginas de las bibliotecas la cual es mantenida y actualizada por la comunidad. También sería imposible no agradecer a los trabajos y tutoriales compartidos por Sebastian Raschka, Andreas Muller, Kyle Kastner y ..., entre otros. Los cuales han sevido de guía para el desarrollo de este material.
